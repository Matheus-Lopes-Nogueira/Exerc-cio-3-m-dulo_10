# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("previsao_de_renda.csv")
df["data_ref"] = pd.to_datetime(df["data_ref"])
df_grouped = df.groupby("data_ref")[["posse_de_imovel", "posse_de_veiculo"]].sum()

df_grouped.plot(kind="bar", figsize=(12, 6))
plt.title("Distribuição de posse de imóvel e veículo ao longo do tempo")
plt.ylabel("Quantidade")
plt.xlabel("Data")
plt.xticks(rotation=45)
plt.legend(["Posse de Imóvel", "Posse de Veículo"])
plt.show()

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
df = pd.read_csv("previsao_de_renda.csv")
df["data_ref"] = pd.to_datetime(df["data_ref"])
df_mean = df.groupby(["data_ref", "posse_de_imovel"])["renda"].mean().unstack()
df_mean.plot(figsize=(10, 5), marker="o")
plt.title("Média da Renda por Posse de Imóvel ao Longo do Tempo")
plt.ylabel("Média da Renda")
plt.xlabel("Data")
plt.xticks(rotation=45)
plt.legend(["Não possui imóvel", "Possui imóvel"])
plt.show()

df_mean = df.groupby(["data_ref", "posse_de_veiculo"])["renda"].mean().unstack()
df_mean.plot(figsize=(10, 5), marker="o")
plt.title("Média da Renda por Posse de Veículo ao Longo do Tempo")
plt.ylabel("Média da Renda")
plt.xlabel("Data")
plt.xticks(rotation=45)
plt.legend(["Não possui veículo", "Possui veículo"])
plt.show()
